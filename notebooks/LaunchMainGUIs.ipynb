# %% [markdown]
# # Example of Launching GUIs from script

# %%
import palmettobug as pbug
import isosegdenoise as iSD

# %%
'''
To launch the GUI programs, and not use by scripting, you can also use these commands:
'''
pbug.run_GUI()

# %%
directory = None    ## or specify a project directory to launch the iSD subprogram inside that project
resolutions = [1.0, 1.0]
iSD.run_GUI(directory = directory, resolutions = resolutions)
